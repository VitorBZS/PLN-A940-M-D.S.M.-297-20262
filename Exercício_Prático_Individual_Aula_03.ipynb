# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorBZS/PLN-A940-M-D.S.M.-297-20262/blob/main/Exerc%C3%ADcio_Pr%C3%A1tico_Individual_Aula_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalação e download de recursos(Rodar 1x)

# !pip install -q nltk spacy pandas
# !python -m spacy download pt_core_news_sm -q

import nltk
import spacy
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import RSLPStemmer

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('rslp', quiet=True)

nlp = spacy.load("pt_core_news_sm")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 61.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Espaço do aluno — escreva seu pipeline completo aqui
frase_exercicio = "As reformas recentes valorizaram bastante o imóvel da esquina."

# 1. Tokenização com spaCy
doc_ancora = nlp(frase_exercicio)

# 2. Remoção de pontuação e stopwords
tokens_sem_stopwords_spacy = [token.text for token in doc_ancora if not token.is_stop and not token.is_punct]
print(tokens_sem_stopwords_spacy)
# Out:
# ['reformas', 'recentes', 'valorizaram', 'imóvel', 'esquina']

# %%
# 3. Stemming (RSLP)
stemmer = RSLPStemmer()
stems = [stemmer.stem(t) for t in tokens_sem_stopwords_spacy]

for original, stem in zip(tokens_sem_stopwords_spacy, stems):
  print(f"{original:15} -> {stem}")
# Out:
# reformas        -> reform
# recentes        -> recent
# valorizaram     -> valoriz
# imóvel          -> imóvel
# esquina         -> esquin

# %%
# 4. Lematização (spaCy)
doc_limpo = nlp(" ".join(tokens_sem_stopwords_spacy))

for token in doc_limpo:
  print(f"{token.text:15} -> {token.lemma_}")
# Out:
# reformas        -> reforma
# recentes        -> recente
# valorizaram     -> valorizar
# imóvel          -> imóvel
# esquina         -> esquina

# %%
# 5. Tabela comparativa

comparacao = pd.DataFrame({
    "Token original": tokens_sem_stopwords_spacy,
    "Stemming (RSLP)": stems,
    "Lematização (spaCy)": [t.lemma_ for t in doc_limpo]
})
comparacao
# Out:
#   Token original Stemming (RSLP) Lematização (spaCy)
# 0       reformas          reform             reforma
# 1       recentes          recent             recente
# 2    valorizaram         valoriz           valorizar
# 3         imóvel          imóvel              imóvel
# 4        esquina          esquin             esquina
