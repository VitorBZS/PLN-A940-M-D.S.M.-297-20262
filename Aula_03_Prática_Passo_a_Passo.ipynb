# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorBZS/PLN-A940-M-D.S.M.-297-20262/blob/main/Aula_03_Pr%C3%A1tica_Passo_a_Passo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalação e download de recursos(Rodar 1x)

# !pip install -q nltk spacy pandas
# !python -m spacy download pt_core_news_sm -q

import nltk
import spacy
import pandas as pd

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('rslp', quiet=True)

nlp = spacy.load("pt_core_news_sm")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 76.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
frase_ancora = "O banco aprovou o empréstimo ontem."

doc_ancora = nlp(frase_ancora)
tokens_sem_pontuacao = [token.text for token in doc_ancora if not token.is_punct]

print("Tokens sem pontuação:", tokens_sem_pontuacao)
# Out:
# Tokens sem pontuação: ['O', 'banco', 'aprovou', 'o', 'empréstimo', 'ontem']

# %%
from nltk.corpus import stopwords

stop_pt = set(stopwords.words('portuguese'))
print(f"Total de stopwords em portguês(NLTK): {len(stop_pt)}")
print(list(stop_pt)[:15])
# Out:
# Total de stopwords em portguês(NLTK): 207
# ['da', 'minha', 'estive', 'sejam', 'estivesse', 'pela', 'houverá', 'este', 'aquele', 'houvera', 'tém', 'tem', 'fomos', 'estamos', 'o']

# %%
# 2.1 Removendo stopwords com NLTK (a partir da lista de tokens)

tokens_sem_stopwords_nltk = [t for t in tokens_sem_pontuacao if t.lower() not in stop_pt]

print("Antes: ", tokens_sem_pontuacao)

print("Depois:", tokens_sem_stopwords_nltk)
# Out:
# Antes:  ['O', 'banco', 'aprovou', 'o', 'empréstimo', 'ontem']
# Depois: ['banco', 'aprovou', 'empréstimo', 'ontem']

# %%
# 2.2 Removendo stopwords nativamente com spaCy (token.is_stop)
tokens_sem_stopwords_spacy = [token.text for token in doc_ancora if not token.is_stop and not token.is_punct]

print("Tokens sem stopwords/pontuação (spaCy):", tokens_sem_stopwords_spacy)
# Out:
# Tokens sem stopwords/pontuação (spaCy): ['banco', 'aprovou', 'empréstimo']

# %% [markdown]
# ## Steamming

# %%
from nltk.stem import RSLPStemmer

stemmer = RSLPStemmer()
stems = [stemmer.stem(t) for t in tokens_sem_stopwords_nltk]

for original, stem in zip(tokens_sem_stopwords_nltk, stems):
    print(f"{original:15} -> {stem}")
# Out:
# banco           -> banc
# aprovou         -> aprov
# empréstimo      -> emprést
# ontem           -> ont

# %% [markdown]
# ## Lematização

# %%
doc_limpo = nlp(" ".join(tokens_sem_stopwords_nltk))

for token in doc_limpo:
    print(f"{token.text:15} -> {token.lemma_}")
# Out:
# banco           -> Banco
# aprovou         -> aprovar
# empréstimo      -> empréstimo
# ontem           -> ontem

# %% [markdown]
# ## Comparação Steamming x Lematização

# %%
comparacao = pd.DataFrame({
    "Token original": tokens_sem_stopwords_nltk,
    "Stemming (RSLP)": stems,
    "Lematização (spaCy)": [t.lemma_ for t in doc_limpo]
})
comparacao
# Out:
#   Token original Stemming (RSLP) Lematização (spaCy)
# 0          banco            banc               Banco
# 1        aprovou           aprov             aprovar
# 2     empréstimo         emprést          empréstimo
# 3          ontem             ont               ontem
