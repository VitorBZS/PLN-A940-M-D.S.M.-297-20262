# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorBZS/PLN-A940-M-D.S.M.-297-20262/blob/main/Exerc%C3%ADcio_Pr%C3%A1tico_Individual_Aula_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q spacy pandas
# !python -m spacy download pt_core_news_sm -q

import spacy
import pandas as pd
from spacy import displacy

nlp = spacy.load("pt_core_news_sm")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 70.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Espaço do aluno — escreva seu código aqui
frase_exercicio = "O corretor apresentou o imóvel para o cliente ontem."

# 1. POS Tagging

doc = nlp(frase_exercicio)
dados_pos = []
for token in doc:
  dados_pos.append({
    "Token": token.text,
    "POS(Classe Geral)": token.pos_,
    "Tag (Detalhada)": token.tag_
  })

df_pos = pd.DataFrame(dados_pos)
df_pos
# Out:
#         Token POS(Classe Geral) Tag (Detalhada)
# 0           O               DET             DET
# 1    corretor              NOUN            NOUN
# 2  apresentou              VERB            VERB
# 3           o               DET             DET
# 4      imóvel              NOUN            NOUN
# 5        para               ADP             ADP
# 6           o               DET             DET
# 7     cliente              NOUN            NOUN
# 8       ontem               ADV             ADV
# 9           .             PUNCT           PUNCT

# %%
# 2. Visualização com displacy
displacy.render(doc, style="dep", jupyter=True, options={"distance": 100, "collapse_punct": False})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="09313a8f6bae461591ba0910335866da-0" class="displacy" width="1050" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">corretor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
# ...

# %%
# 3. Extração do SN e do SV

raiz = [token for token in doc if token.dep_ == "ROOT"][0]

sujeito = [token for token in doc if token.dep_ == "nsubj"][0]

sintagma_n = list(sujeito.subtree)
print("Sintagma Nominal (SN):", [t.text for t in sintagma_n])

sintagma_v = [t for t in raiz.subtree if t not in sintagma_n]
print("Sintagma Verbal (SV):", [t.text for t in sintagma_v])
# Out:
# Sintagma Nominal (SN): ['O', 'corretor']
# Sintagma Verbal (SV): ['apresentou', 'o', 'imóvel', 'para', 'o', 'cliente', 'ontem', '.']
